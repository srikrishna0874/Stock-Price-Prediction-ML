# %%
import requests

# %%
import requests

payload = { 'api_key': '5076c71ac938639eeaf523c7ff392bfa','query':'Artificial Intelligence','num':2}
r = requests.get('https://api.scraperapi.com/structed/twitter/search', params=payload)
r
# Out:
# <Response [404]>

# %%
import json

# %%
import feedparser
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import feedparser
#
# ModuleNotFoundError: No module named 'feedparser'

# %%
pip install feedparser
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import feedparser

# %%
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0'
}

# %%
ticker = 'AMZN'

# %%
rssfeedurl = 'https://feeds.finance.yahoo.com/rss/2.0/headline?s=%s&region=US&lang=en-US'%ticker

# %%
NewsFeed = feedparser.parse(rssfeedurl)

# %%
type(NewsFeed)
# Out:
# feedparser.util.FeedParserDict

# %%
NewsFeed.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
NewsFeed
# Out:
# {'bozo': False,
#  'entries': [{'summary': 'In this article, we will discuss the 11 Best Alternatives to Aquaphor and Petroleum Jelly. You can skip our detailed analysis of the global skincare market, beauty and sustainability come together, and skincare companies are developing and using eco-friendly practices, go directly to the 5 Best Alternatives to Aquaphor and Petroleum Jelly. The ultimate form […]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.finance.yahoo.com/rss/2.0/headline?s=AMZN&region=US&lang=en-US',
#     'value': 'In this article, we will discuss the 11 Best Alternatives to Aquaphor and Petroleum Jelly. You can skip our detailed analysis of the global skincare market, beauty and sustainability come together, and skincare companies are developing and using eco-friendly practices, go directly to the 5 Best Alternatives to Aquaphor and Petroleum Jelly. The ultimate form […]'},
# ...

# %%
len(NewsFeed.entries)
# Out:
# 20

# %%
NewsFeed.entries[0]
# Out:
# {'summary': 'In this article, we will discuss the 11 Best Alternatives to Aquaphor and Petroleum Jelly. You can skip our detailed analysis of the global skincare market, beauty and sustainability come together, and skincare companies are developing and using eco-friendly practices, go directly to the 5 Best Alternatives to Aquaphor and Petroleum Jelly. The ultimate form […]',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://feeds.finance.yahoo.com/rss/2.0/headline?s=AMZN&region=US&lang=en-US',
#   'value': 'In this article, we will discuss the 11 Best Alternatives to Aquaphor and Petroleum Jelly. You can skip our detailed analysis of the global skincare market, beauty and sustainability come together, and skincare companies are developing and using eco-friendly practices, go directly to the 5 Best Alternatives to Aquaphor and Petroleum Jelly. The ultimate form […]'},
#  'id': '3dbbc986-d0f4-3f71-bff1-c68a86030c3b',
#  'guidislink': False,
# ...

# %%
NewsFeed.entries[0].summary
# Out:
# 'In this article, we will discuss the 11 Best Alternatives to Aquaphor and Petroleum Jelly. You can skip our detailed analysis of the global skincare market, beauty and sustainability come together, and skincare companies are developing and using eco-friendly practices, go directly to the 5 Best Alternatives to Aquaphor and Petroleum Jelly. The ultimate form […]'

# %%
for i in range(len(NewsFeed.entries)):
    print(NewsFeed.entries[i].summary)
    print()
    print()
    print()
    print()
# Out:
# In this article, we will discuss the 11 Best Alternatives to Aquaphor and Petroleum Jelly. You can skip our detailed analysis of the global skincare market, beauty and sustainability come together, and skincare companies are developing and using eco-friendly practices, go directly to the 5 Best Alternatives to Aquaphor and Petroleum Jelly. The ultimate form […]
#
#
#
#
# In this article, we will look into the 20 countries that spend the most on research and development. If you want to skip our detailed analysis you can go directly to the 5 Countries that Spend the Most on Research and Development. Global R&amp;D Outlook According to the R&amp;D report by AAAS, global investments in […]
#
#
#
#
# Which of these retailers has a brighter future?
#
#
#
#
# Amazon Prime offers free shipping and lots of other valuable benefits. Find out about the rarely mentioned drawbacks before you get a membership.
#
#
#
#
# ...
